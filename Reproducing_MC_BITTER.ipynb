# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
save_folder = '/content/drive/MyDrive/PCABITTER/'

# %% [markdown]
# On essaye de reproduire les résultats de https://doi.org/10.1038/s41586-024-07834-x à l'aide de python.

# %%
# !pip3 install pyreadr
 #pour pouvoir enregistrer automatiquement les figures
# Out:
# Collecting pyreadr
#   Downloading pyreadr-0.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyreadr) (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->pyreadr) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->pyreadr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->pyreadr) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2.0->pyreadr) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadr) (1.17.0)
# Downloading pyreadr-0.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (411 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.7/411.7 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: pyreadr
# Successfully installed pyreadr-0.5.3

# %%
pip install altair_saver
# Out:
# Collecting altair_saver
#   Downloading altair_saver-0.5.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: altair in /usr/local/lib/python3.11/dist-packages (from altair_saver) (5.5.0)
# Collecting altair-data-server>=0.4.0 (from altair_saver)
#   Downloading altair_data_server-0.4.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting altair-viewer (from altair_saver)
#   Downloading altair_viewer-0.4.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting selenium (from altair_saver)
#   Downloading selenium-4.29.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: portpicker in /usr/local/lib/python3.11/dist-packages (from altair-data-server>=0.4.0->altair_saver) (1.5.2)
# Requirement already satisfied: tornado in /usr/local/lib/python3.11/dist-packages (from altair-data-server>=0.4.0->altair_saver) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair->altair_saver) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair->altair_saver) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair->altair_saver) (1.29.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair->altair_saver) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from altair->altair_saver) (4.12.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium->altair_saver) (2.3.0)
# Collecting trio~=0.17 (from selenium->altair_saver)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium->altair_saver)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium->altair_saver) (2025.1.31)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium->altair_saver) (1.8.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->altair_saver) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->altair_saver) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->altair_saver) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->altair_saver) (0.23.1)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->altair_saver) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->altair_saver) (3.10)
# Collecting outcome (from trio~=0.17->selenium->altair_saver)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium->altair_saver) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium->altair_saver)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium->altair_saver) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair->altair_saver) (3.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from portpicker->altair-data-server>=0.4.0->altair_saver) (5.9.5)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium->altair_saver) (0.14.0)
# Downloading altair_saver-0.5.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 3.4 MB/s eta 0:00:00
# Downloading altair_data_server-0.4.1-py3-none-any.whl (12 kB)
# Downloading altair_viewer-0.4.0-py3-none-any.whl (844 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 844.5/844.5 kB 18.7 MB/s eta 0:00:00
# Downloading selenium-4.29.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 66.4 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 22.4 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium, altair-data-server, altair-viewer, altair_saver
# Successfully installed altair-data-server-0.4.1 altair-viewer-0.4.0 altair_saver-0.5.0 outcome-1.3.0.post0 selenium-4.29.0 trio-0.29.0 trio-websocket-0.12.2 wsproto-1.2.0

# %%
from altair_saver import save

# %%
import pyreadr
result = pyreadr.read_r('/content/drive/MyDrive/orch2021_Downsampled_ECage_Filtered.RData') # also works for Rds

# %%
df=result.copy()
df
# Out:
# OrderedDict([('samps',
#                                           full.sample.name   sample cage tpt treatment  \
#               rownames
#               tp1_F1_E1_downsamped    tp1_F1_E1_downsamped   tp1_E1   E1   1         E
#               tp1_F1_E10_downsamped  tp1_F1_E10_downsamped  tp1_E10  E10   1         E
#               tp1_F1_E11_downsamped  tp1_F1_E11_downsamped  tp1_E11  E11   1         E
#               tp1_F1_E12_downsamped  tp1_F1_E12_downsamped  tp1_E12  E12   1         E
#               tp1_F1_E2_downsamped    tp1_F1_E2_downsamped   tp1_E2   E2   1         E
#               ...                                      ...      ...  ...  ..       ...
#               tp9_F1_E5_downsamped    tp9_F1_E5_downsamped   tp9_E5   E5   9         E
#               tp9_F1_E6_downsamped    tp9_F1_E6_downsamped   tp9_E6   E6   9         E
#               tp9_F1_E7_downsamped    tp9_F1_E7_downsamped   tp9_E7   E7   9         E
#               tp9_F1_E8_downsamped    tp9_F1_E8_downsamped   tp9_E8   E8   9         E
#               tp9_F1_E9_downsamped    tp9_F1_E9_downsamped   tp9_E9   E9   9         E
#
#                                     biol.rep tech.rep
#               rownames
#               tp1_F1_E1_downsamped        No       No
#               tp1_F1_E10_downsamped       No       No
#               tp1_F1_E11_downsamped       No       No
#               tp1_F1_E12_downsamped       No       No
#               tp1_F1_E2_downsamped        No       No
#               ...                        ...      ...
#               tp9_F1_E5_downsamped        No       No
#               tp9_F1_E6_downsamped        No       No
#               tp9_F1_E7_downsamped        No       No
#               tp9_F1_E8_downsamped        No       No
#               tp9_F1_E9_downsamped        No       No
#
#               [139 rows x 7 columns]),
#              ('sites',
#                       chrom       pos
#               0          2L      5390
#               1          2L      5399
#               2          2L      5465
#               3          2L      5495
#               4          2L      5598
#               ...       ...       ...
#               1975157     X  22354846
#               1975158     X  22354855
#               1975159     X  22355146
#               1975160     X  22356881
#               1975161     X  22356899
#
#               [1975162 rows x 2 columns]),
#              ('afmat',
#                        tp1_F1_E1_downsamped  tp1_F1_E10_downsamped  tp1_F1_E11_downsamped  \
#               1                    0.362549               0.326127               0.344419
#               2                    0.022144               0.011422               0.013808
#               3                    0.141020               0.105532               0.101646
#               4                    0.021024               0.021402               0.028597
#               5                    0.103809               0.088658               0.080403
#               ...                       ...                    ...                    ...
#               1975158              0.025067               0.027345               0.025766
#               1975159              0.024695               0.026933               0.025357
#               1975160              0.049179               0.050533               0.048672
#               1975161              0.149301               0.161747               0.155052
#               1975162              0.147256               0.157898               0.149352
#
#                        tp1_F1_E12_downsamped  tp1_F1_E2_downsamped  tp1_F1_E4_downsamped  \
#               1                     0.311698              0.324808              0.276709
#               2                     0.025414              0.009689              0.029413
#               3                     0.103317              0.093072              0.097851
#               4                     0.033147              0.016302              0.019807
#               5                     0.076573              0.066145              0.070540
#               ...                        ...                   ...                   ...
#               1975158               0.027836              0.027186              0.028645
#               1975159               0.026454              0.026706              0.028552
#               1975160               0.044522              0.050469              0.048290
#               1975161               0.143517              0.144037              0.149685
#               1975162               0.141051              0.140663              0.148262
#
#                        tp1_F1_E5_downsamped  tp1_F1_E6_downsamped  tp1_F1_E8_downsamped  \
#               1                    0.403539              0.373116              0.286292
#               2                    0.024946              0.017815              0.048670
#               3                    0.175157              0.135034              0.124523
#               4                    0.033699              0.018351              0.021528
#               5                    0.122271              0.100438              0.093345
#               ...                       ...                   ...                   ...
#               1975158              0.029983              0.024672              0.028517
#               1975159              0.029312              0.024241              0.028158
#               1975160              0.048170              0.046067              0.053144
#               1975161              0.160879              0.152548              0.155338
#               1975162              0.158280              0.146640              0.152193
#
#                        tp1_F1_E9_downsamped  ...  tp9_F1_E11_downsamped  \
#               1                    0.337459  ...               0.399451
#               2                    0.021328  ...               0.014186
#               3                    0.081292  ...               0.169537
#               4                    0.034739  ...               0.020107
#               5                    0.062821  ...               0.128704
#               ...                       ...  ...                    ...
#               1975158              0.028883  ...               0.022562
#               1975159              0.028238  ...               0.022310
#               1975160              0.046031  ...               0.034067
#               1975161              0.159019  ...               0.158016
#               1975162              0.154709  ...               0.151468
#
#                        tp9_F1_E12_downsamped  tp9_F1_E2_downsamped  tp9_F1_E3_downsamped  \
#               1                     0.355522              0.307547              0.408936
#               2                     0.008824              0.010539              0.009476
#               3                     0.166208              0.119835              0.193437
#               4                     0.015356              0.015779              0.015717
#               5                     0.128596              0.092435              0.148294
#               ...                        ...                   ...                   ...
#               1975158               0.029761              0.026309              0.022417
#               1975159               0.028825              0.026319              0.022386
#               1975160               0.042548              0.042477              0.043960
#               1975161               0.155964              0.151522              0.158110
#               1975162               0.148418              0.142359              0.153677
#
#                        tp9_F1_E4_downsamped  tp9_F1_E5_downsamped  tp9_F1_E6_downsamped  \
#               1                    0.434343              0.344607              0.376767
#               2                    0.012122              0.032006              0.013765
#               3                    0.185050              0.137323              0.148580
#               4                    0.016144              0.017053              0.012508
#               5                    0.144749              0.106348              0.111221
#               ...                       ...                   ...                   ...
#               1975158              0.021049              0.023263              0.024736
#               1975159              0.020573              0.022956              0.023889
#               1975160              0.043886              0.038770              0.045452
#               1975161              0.139760              0.159135              0.148645
#               1975162              0.132846              0.153611              0.141636
#
#                        tp9_F1_E7_downsamped  tp9_F1_E8_downsamped  tp9_F1_E9_downsamped
#               1                    0.417602              0.313845              0.406535
#               2                    0.016689              0.013491              0.009690
#               3                    0.191413              0.144492              0.224814
#               4                    0.012047              0.011621              0.022538
#               5                    0.153035              0.111749              0.163402
#               ...                       ...                   ...                   ...
#               1975158              0.038847              0.028331              0.029387
#               1975159              0.038621              0.027973              0.028357
#               1975160              0.039330              0.049777              0.037812
#               1975161              0.163979              0.138158              0.145467
#               1975162              0.159577              0.136512              0.138002
#
#               [1975162 rows x 139 columns]),
#              ('eec',
#                        tp1_F1_E1_downsamped  tp1_F1_E10_downsamped  tp1_F1_E11_downsamped  \
#               1                  419.567281             408.729368             407.194093
#               2                  419.567281             408.729368             407.194093
#               3                  419.567281             408.729368             407.194093
#               4                  419.567281             408.729368             407.194093
#               5                  419.567281             408.729368             407.194093
#               ...                       ...                    ...                    ...
#               1975158            301.358769             293.253938             290.401271
#               1975159            301.358769             293.253938             290.401271
#               1975160            301.358769             293.253938             290.401271
#               1975161            301.358769             293.253938             290.401271
#               1975162            301.358769             293.253938             290.401271
#
#                        tp1_F1_E12_downsamped  tp1_F1_E2_downsamped  tp1_F1_E4_downsamped  \
#               1                   407.120828            411.155799            406.274725
#               2                   407.120828            411.155799            406.274725
#               3                   407.120828            411.155799            406.274725
#               4                   407.120828            411.155799            406.274725
#               5                   407.120828            411.155799            406.274725
#               ...                        ...                   ...                   ...
#               1975158             292.253281            295.189841            291.682861
#               1975159             292.253281            295.189841            291.682861
#               1975160             292.253281            295.189841            291.682861
#               1975161             292.253281            295.189841            291.682861
#               1975162             292.253281            295.189841            291.682861
#
#                        tp1_F1_E5_downsamped  tp1_F1_E6_downsamped  tp1_F1_E8_downsamped  \
#               1                  412.653022            407.962908            405.496172
#               2                  412.653022            407.962908            405.496172
#               3                  412.653022            407.962908            405.496172
#               4                  412.653022            407.962908            405.496172
#               5                  412.653022            407.962908            405.496172
#               ...                       ...                   ...                   ...
#               1975158            297.309144            293.122642            289.348328
#               1975159            297.309144            293.122642            289.348328
#               1975160            297.309144            293.122642            289.348328
#               1975161            297.309144            293.122642            289.348328
#               1975162            297.309144            293.122642            289.348328
#
#                        tp1_F1_E9_downsamped  ...  tp9_F1_E11_downsamped  \
#               1                  408.468088  ...             303.283218
#               2                  408.468088  ...             303.283218
#               3                  408.468088  ...             303.283218
#               4                  408.468088  ...             303.283218
#               5                  408.468088  ...             303.283218
#               ...                       ...  ...                    ...
#               1975158            293.550767  ...             218.294756
#               1975159            293.550767  ...             218.294756
#               1975160            293.550767  ...             218.294756
#               1975161            293.550767  ...             218.294756
#               1975162            293.550767  ...             218.294756
#
#                        tp9_F1_E12_downsamped  tp9_F1_E2_downsamped  tp9_F1_E3_downsamped  \
#               1                   303.536864            304.831320            302.784869
#               2                   303.536864            304.831320            302.784869
#               3                   303.536864            304.831320            302.784869
#               4                   303.536864            304.831320            302.784869
#               5                   303.536864            304.831320            302.784869
#               ...                        ...                   ...                   ...
#               1975158             217.460011            220.652534            219.451895
#               1975159             217.460011            220.652534            219.451895
#               1975160             217.460011            220.652534            219.451895
#               1975161             217.460011            220.652534            219.451895
#               1975162             217.460011            220.652534            219.451895
#
#                        tp9_F1_E4_downsamped  tp9_F1_E5_downsamped  tp9_F1_E6_downsamped  \
#               1                  304.494317            305.733955            305.607974
#               2                  304.494317            305.733955            305.607974
#               3                  304.494317            305.733955            305.607974
#               4                  304.494317            305.733955            305.607974
#               5                  304.494317            305.733955            305.607974
#               ...                       ...                   ...                   ...
#               1975158            219.452095            220.140396            218.970184
#               1975159            219.452095            220.140396            218.970184
#               1975160            219.452095            220.140396            218.970184
#               1975161            219.452095            220.140396            218.970184
#               1975162            219.452095            220.140396            218.970184
#
#                        tp9_F1_E7_downsamped  tp9_F1_E8_downsamped  tp9_F1_E9_downsamped
#               1                  302.464487            302.785385            305.115545
#               2                  302.464487            302.785385            305.115545
#               3                  302.464487            302.785385            305.115545
#               4                  302.464487            302.785385            305.115545
#               5                  302.464487            302.785385            305.115545
#               ...                       ...                   ...                   ...
#               1975158            217.573011            218.550030            221.027473
#               1975159            217.573011            218.550030            221.027473
#               1975160            217.573011            218.550030            221.027473
#               1975161            217.573011            218.550030            221.027473
#               1975162            217.573011            218.550030            221.027473
#
#               [1975162 rows x 139 columns])])

# %%
import pandas as pd
import altair as alt
from sklearn.decomposition import PCA

# %%
afmat=df['afmat']
sites=df['sites']
samsp=df['samps']

samsp=samsp.rename(columns={"tpt": "Timepoint"})

timepoints = samsp.loc[afmat.columns, 'Timepoint'].values

pca = PCA(n_components=2)
pca.fit(afmat.T)  # Transpose pour que les échantillons soient en lignes
to_plot = pca.transform(afmat.T)

# %%
print(pca.explained_variance_ratio_)
print(pca.singular_values_)
# Out:
# [0.06537953 0.04688265]
# [106.64961648  90.3117906 ]

# %%
df_plot=samsp.copy()
df_plot['PC1'] = to_plot[:, 0]
df_plot['PC2'] = to_plot[:, 1]
df_plot #regarde en detail le df
# Out:
#                             full.sample.name   sample cage Timepoint  \
# rownames
# tp1_F1_E1_downsamped    tp1_F1_E1_downsamped   tp1_E1   E1         1
# tp1_F1_E10_downsamped  tp1_F1_E10_downsamped  tp1_E10  E10         1
# tp1_F1_E11_downsamped  tp1_F1_E11_downsamped  tp1_E11  E11         1
# tp1_F1_E12_downsamped  tp1_F1_E12_downsamped  tp1_E12  E12         1
# tp1_F1_E2_downsamped    tp1_F1_E2_downsamped   tp1_E2   E2         1
# ...                                      ...      ...  ...       ...
# tp9_F1_E5_downsamped    tp9_F1_E5_downsamped   tp9_E5   E5         9
# tp9_F1_E6_downsamped    tp9_F1_E6_downsamped   tp9_E6   E6         9
# tp9_F1_E7_downsamped    tp9_F1_E7_downsamped   tp9_E7   E7         9
# tp9_F1_E8_downsamped    tp9_F1_E8_downsamped   tp9_E8   E8         9
# tp9_F1_E9_downsamped    tp9_F1_E9_downsamped   tp9_E9   E9         9
#
#                       treatment biol.rep tech.rep        PC1        PC2
# rownames
# tp1_F1_E1_downsamped          E       No       No  10.202694 -19.660559
# tp1_F1_E10_downsamped         E       No       No  11.008865  -4.058722
# tp1_F1_E11_downsamped         E       No       No   8.600170  -0.761213
# tp1_F1_E12_downsamped         E       No       No  11.097854   4.095605
# tp1_F1_E2_downsamped          E       No       No   9.765441  -2.007235
# ...                         ...      ...      ...        ...        ...
# tp9_F1_E5_downsamped          E       No       No  10.132795  15.974624
# tp9_F1_E6_downsamped          E       No       No   0.527779  -4.197282
# tp9_F1_E7_downsamped          E       No       No  -8.460223   0.898020
# tp9_F1_E8_downsamped          E       No       No  -5.265305   0.946416
# tp9_F1_E9_downsamped          E       No       No  -3.506674   1.785282
#
# [139 rows x 9 columns]

# %%
alt.Chart(df_plot).mark_point().encode(
    x='PC1',
    y='PC2',
    color=alt.Color('Timepoint', scale=alt.Scale(scheme='turbo'))
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df_plot).mark_point().encode(
    x='PC1',
    y='PC2',
    color=alt.Color('cage', scale=alt.Scale(scheme='turbo'))
)
# Out:
# alt.Chart(...)

# %%
#Maintenant on veut faire des PCA pour chaque chromosome
#afmat
#sites
#On veut regrouper les données de PCA selon le chromosome
#sites2 = sites.transpose()
#print(len(sites))
afmat2 = afmat.copy()

# %%
#sites2["nom du chromosome"]["position"]
#afmat2["numéro SNP"]["valeur SNP selon génome 1-139"]
poschrom=sites.groupby(['chrom']).count()
poschrom
#On sait qu'on a en tout 1975162 SNP et qu'ils sont dans l'ordre de séquençage des chromosomes.
#Donc 2L va de [0-453444] 2R de [453445-827200] 3L [827201-1272657] 3R[1272658-1720665] X[1720666-1975162]
#En connaissant la taille des chromosomes selon leur nb de pos, on peut déduire les subset de données qu'ils constituent dans le df initial.
#On peut ensuite diviser le subset initial selon cette taille et run des PCA selon chaque chromosome.
df_2L=afmat.iloc[0:453444]
df_2R=afmat.iloc[453445:827200]
df_3L=afmat.iloc[827201:1272657]
df_3R=afmat.iloc[1272658:1720665]
df_X=afmat.iloc[1720666-1975162]
list_chr=[df_2L,df_2R,df_3L,df_3R,df_X]
name_chr=['2L','2R','3L','3R','X']
#On sub run des PCA sur ces différents datasets par la suite.

# %%
#On automatise les PCA.
pcax=PCA(n_components=2)
for i in range(5):
  pcax.fit(list_chr[i].T)
  toplot=pcax.transform(list_chr[i].T)
  plot_chr=samsp.copy()
  plot_chr['PC1']=toplot[:,0]
  plot_chr['PC2']=toplot[:,1]
  chart=alt.Chart(plot_chr,title=name_chr[i]).mark_point().encode(
    x='PC1',
    y='PC2',
    color=alt.Color('cage', scale=alt.Scale(scheme='turbo')))
  chart.save('pca.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1a673c586da6> in <cell line: 0>()
#      11     y='PC2',
#      12     color=alt.Color('cage', scale=alt.Scale(scheme='turbo')))
# ---> 13   chart.save('pca.png')
#
# /usr/local/lib/python3.11/dist-packages/altair/vegalite/v5/api.py in save(self, fp, format, override_data_transformer, scale_factor, mode, vegalite_version, vega_version, vegaembed_version, embed_options, json_kwds, engine, inline, **kwargs)
#    2287         if override_data_transformer:
#    2288             with data_transformers.disable_max_rows():
# -> 2289                 save(**kwds)
#    2290         else:
#    2291             save(**kwds)
#
# /usr/local/lib/python3.11/dist-packages/altair/utils/save.py in save(chart, fp, vega_version, vegaembed_version, format, mode, vegalite_version, embed_options, json_kwds, scale_factor, engine, inline, **kwargs)
#     222         # described at https://github.com/vega/vl-convert/issues/31
#     223         with data_transformers.enable("default"), data_transformers.disable_max_rows():
# --> 224             perform_save()
#
# /usr/local/lib/python3.11/dist-packages/altair/utils/save.py in perform_save()
#     173             )
#     174         elif format == "png":
# --> 175             mb_png = spec_to_mimebundle(
#     176                 spec=spec,
#     177                 format=format,
#
# /usr/local/lib/python3.11/dist-packages/altair/utils/mimebundle.py in spec_to_mimebundle(spec, format, mode, vega_version, vegaembed_version, vegalite_version, embed_options, engine, **kwargs)
#     139
#     140     if format in {"png", "svg", "pdf", "vega"}:
# --> 141         return _spec_to_mimebundle_with_engine(
#     142             spec,
#     143             cast(Literal["png", "svg", "pdf", "vega"], format),
#
# /usr/local/lib/python3.11/dist-packages/altair/utils/mimebundle.py in _spec_to_mimebundle_with_engine(spec, format, mode, format_locale, time_format_locale, **kwargs)
#     209     # and removing underscores and hyphens
#     210     engine = kwargs.pop("engine", None)
# --> 211     normalized_engine = _validate_normalize_engine(engine, format)
#     212
#     213     if normalized_engine == "vlconvert":
#
# /usr/local/lib/python3.11/dist-packages/altair/utils/mimebundle.py in _validate_normalize_engine(engine, format)
#     328                 "see https://altair-viz.github.io/user_guide/saving_charts.html#png-svg-and-pdf-format"
#     329             )
# --> 330             raise ValueError(msg)
#     331     else:
#     332         msg = f"Invalid conversion engine {engine!r}. Expected vl-convert"
#
# ValueError: Saving charts in 'png' format requires the vl-convert-python package: see https://altair-viz.github.io/user_guide/saving_charts.html#png-svg-and-pdf-format

# %%
pca2L=PCA(n_components=2)
pca2L.fit(df_2L.T)
tplt2L=pca2L.transform(df_2L.T)
print(pca2L.explained_variance_ratio_)
print(pca2L.singular_values_)
# Out:
# [0.07914403 0.07051901]
# [57.6010606  54.37189689]

# %%
plt2L=samsp.copy()
plt2L['PC1']=tplt2L[:,0]
plt2L['PC2']=tplt2L[:,1]

alt.Chart(plt2L).mark_point().encode(
    x='PC1',
    y='PC2',
    color=alt.Color('cage', scale=alt.Scale(scheme='turbo'))
)
# Out:
# alt.Chart(...)
